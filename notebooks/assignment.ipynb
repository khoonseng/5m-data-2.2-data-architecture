# %% [markdown]
# Question: How would you create a new hash in Redis to store information about a person, with john_doe as the key and include the name (John Doe), age (35), and email address (john@email.com)?

# %%
import os
import redis
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
REDIS_HOST = os.getenv('REDIS_HOST')
REDIS_PORT = os.getenv('REDIS_PORT')
REDIS_USERNAME = os.getenv('REDIS_USERNAME')
REDIS_PASSWORD = os.getenv('REDIS_PASSWORD')

import redis

r = redis.Redis(
    host=REDIS_HOST,
    port=REDIS_PORT,
    decode_responses=True,
    username=REDIS_USERNAME,
    password=REDIS_PASSWORD,
)

success = r.set('foo', 'bar')
# True

result = r.get('foo')
print(result)
# >>> bar
# Out:
# bar

# %%
r.hset( 
    'john_doe',
    mapping={
        "name" : "John Doe",
        "age": 35,
        "email address": "john@email.com"
    }
)
# Out:
# 3

# %% [markdown]
# Question: Write Python code to list the first 10 objects (blob name) in the "gcp-public-data-landsat" bucket, along with their sizes.

# %% [markdown]
# We will be using the `google-cloud-storage` python library to fetch data from the public [Landsat Collection 1](https://console.cloud.google.com/storage/browser/gcp-public-data-landsat;tab=objects?prefix=&forceOnObjectsSortingFiltering=false) dataset demonstrated just now.

# %%
from google.cloud import storage

client = storage.Client()
bucket = client.get_bucket("gcp-public-data-landsat")

# %%
blobs = bucket.list_blobs()

print(f"Blobs in {bucket.name}:")
for idx, item in enumerate(blobs):
    if idx > 9:
        break    
    print(f"{idx + 1}) Blob Name: {item.name}, Blob Size: {round(item.size/1000000,2)} MB")
# Out:
# Blobs in gcp-public-data-landsat:
# 1) Blob Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_ANG.txt, Blob Size: 0.12 MB
# 2) Blob Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B1.TIF, Blob Size: 75.09 MB
# 3) Blob Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B10.TIF, Blob Size: 40.61 MB
# 4) Blob Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B11.TIF, Blob Size: 39.27 MB
# 5) Blob Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B2.TIF, Blob Size: 76.26 MB
# 6) Blob Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B3.TIF, Blob Size: 76.81 MB
# 7) Blob Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B4.TIF, Blob Size: 78.51 MB
# 8) Blob Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B5.TIF, Blob Size: 80.34 MB
# 9) Blob Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B6.TIF, Blob Size: 76.42 MB
# 10) Blob Name: LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B7.TIF, Blob Size: 73.89 MB
